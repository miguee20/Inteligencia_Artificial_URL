# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.naive_bayes import GaussianNB

# %%
df = sns.load_dataset('penguins')

# %%
df = df.dropna()
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
print(df.describe())
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
print(df['species'].value_counts())
# Out:
# species
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: count, dtype: int64

# %%
sns.pairplot(df, hue='species', palette='viridis')
plt.show()

# %%
X = df['flipper_length_mm']
y = df['body_mass_g']

# %%
X = sm.add_constant(X)

# %%
modelo_reg = sm.OLS(y, X).fit()

# %%
print(modelo_reg.summary2())
# Out:
#                       Results: Ordinary least squares
# ===========================================================================
# Model:                  OLS                Adj. R-squared:       0.761
# Dependent Variable:     body_mass_g        AIC:                  4926.1457
# Date:                   2026-03-07 16:58   BIC:                  4933.7620
# No. Observations:       333                Log-Likelihood:       -2461.1
# Df Model:               1                  F-statistic:          1060.
# Df Residuals:           331                Prob (F-statistic):   3.13e-105
# R-squared:              0.762              Scale:                1.5472e+05
# ---------------------------------------------------------------------------
#                     Coef.    Std.Err.    t     P>|t|    [0.025     0.975]
# ---------------------------------------------------------------------------
# const             -5872.0927 310.2852 -18.9248 0.0000 -6482.4722 -5261.7131
# flipper_length_mm    50.1533   1.5402  32.5622 0.0000    47.1234    53.1831
# ---------------------------------------------------------------------------
# Omnibus:                  5.922           Durbin-Watson:              2.102
# Prob(Omnibus):            0.052           Jarque-Bera (JB):           5.876
# Skew:                     0.325           Prob(JB):                   0.053
# Kurtosis:                 3.025           Condition No.:              2900
# ===========================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is
# correctly specified.
# [2] The condition number is large, 2.9e+03. This might indicate
# that there are strong multicollinearity or other numerical
# problems.

# %%
features = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
X_clf = df[features]
y_clf = df['species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_clf, y_clf, test_size=0.4, stratify=y_clf, random_state=42)

# %%
clf = DecisionTreeClassifier(max_depth=3, random_state=112)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=112)

# %%
y_pred = clf.predict(X_test)
print(f"Precisión del modelo: {metrics.accuracy_score(y_test, y_pred):.2f}")
# Out:
# Precisión del modelo: 0.94

# %%
plt.figure(figsize=(12,8))
plot_tree(clf, feature_names=features, class_names=clf.classes_, filled=True)
plt.show()

# %%
X_k = df[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']]

# %%
# Clasificación con KMeans
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X_k)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='bill_length_mm', y='flipper_length_mm', hue='cluster', palette='Set1')
plt.title('Agrupamiento K-Means de Pingüinos')
plt.show()

# %%
print("Distribución de clusters por especie real:")
print(pd.crosstab(df['species'], df['cluster']))
# Out:
# Distribución de clusters por especie real:
# cluster     0    1   2
# species
# Adelie     38  108   0
# Chinstrap  16   52   0
# Gentoo     48    1  70

# %%
# Clasificacion con Naive Bayes
X_nb = df[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']]
y_nb = df['species']

# %%
x_train_nb, x_test_nb, y_train_nb, y_test_nb = train_test_split(X_nb, y_nb, test_size=0.4, stratify=y_nb, random_state=73)

# %%
modelo_nb = GaussianNB()
